# %% [markdown]
# # Grove pedometer Example
#
# This example shows how to use the [Grove IMU](https://www.seeedstudio.com/Grove-IMU-10DOF-v2-0-p-2691.html) on the Pynq-Z2 board.
# For this notebook, a PYNQ Arduino shield is also required.  The IMU is attached to the I2C connection on the shield.
# We use IMU as a pedometer which counts user's steps.

# %%
# Make sure the base overlay is loaded
from pynq.overlays.base import BaseOverlay
base = BaseOverlay("base.bit")

# %% [markdown]
# ### 1. Instantiate the IMU

# %%
PINS = {"ARDUINO_GROVE_G1":[2,3],"ARDUINO_GROVE_G2":[3,4],"ARDUINO_GROVE_G3":[4,5],"ARDUINO_GROVE_G4":[6,7],
        "ARDUINO_GROVE_G5":[8,9],"ARDUINO_GROVE_G6":[10,11],"ARDUINO_GROVE_G7":[12,13],"ARDUINO_GROVE_I2C":[18,19]}

# %%
#from pynq.lib.arduino import Grove_IMU
from pynq.lib.arduino import G_IMU

# Instantiate Grove IMU on Arduino shield I2C
#imu = Grove_IMU(base.ARDUINO, PINS["ARDUINO_GROVE_I2C"])
imu = G_IMU(base.ARDUINO, PINS["ARDUINO_GROVE_I2C"])

# %% [markdown]
# ### 2. Use IMU demonstrate the direction
# pedometer will update the data every second and count the steps in total.

# %%
from time import sleep

data = []
step = 0

while(1):
    for i in range(8):
        m = 0
        data = imu.get_data()
        [mx, my, mz] = data[3:6]
        m = m + (abs(mx) + abs(my) + abs(mz))
    if m > 50: step = step + 1
    print("{} steps in total.".format(step))
# Out:
# 0 steps in total.
# 0 steps in total.
# 0 steps in total.
# 0 steps in total.
# 0 steps in total.
# 1 steps in total.
# 2 steps in total.
# 2 steps in total.
# 3 steps in total.
# 4 steps in total.
# 5 steps in total.
# 6 steps in total.
# 7 steps in total.
# 7 steps in total.
# 7 steps in total.
# 7 steps in total.
# 7 steps in total.
# 7 steps in total.
# 7 steps in total.
# 7 steps in total.
# 8 steps in total.
# 9 steps in total.
# 9 steps in total.
# 9 steps in total.
# 9 steps in total.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-f55b69df87b6> in <module>()
#       7     for i in range(8):
#       8         m = 0
# ----> 9         data = imu.get_data()
#      10         [mx, my, mz] = data[3:6]
#      11         m = m + (abs(mx) + abs(my) + abs(mz))
#
# /usr/local/lib/python3.6/dist-packages/pynq/lib/arduino/grove_imu.py in get_data(self)
#     135             [9,10]  A list of the value of temperature and pressure.
#     136         """
# --> 137         self.microblaze.write_blocking_command(GET_DATA)
#     138         data = self.microblaze.read_mailbox(0, 11)
#     139         [ax, ay, az,
#
# /usr/local/lib/python3.6/dist-packages/pynq/lib/arduino/arduino.py in write_blocking_command(self, command)
#     153         """
#     154         self.write(MAILBOX_OFFSET + MAILBOX_PY2IOP_CMD_OFFSET, command)
# --> 155         while self.read(MAILBOX_OFFSET + MAILBOX_PY2IOP_CMD_OFFSET) != 0:
#     156             pass
#     157
#
# /usr/local/lib/python3.6/dist-packages/pynq/lib/pynqmicroblaze/pynqmicroblaze.py in read(self, offset, length)
#     304         """
#     305         if length == 1:
# --> 306             return self.mmio.read(offset)
#     307         elif length > 1:
#     308             return [self.mmio.read(offset + 4*i) for i in range(length)]
#
# /usr/local/lib/python3.6/dist-packages/pynq/mmio.py in read(self, offset, length)
#     137
#     138         self._debug('Reading {0} bytes from offset {1:x}',
# --> 139                     length, offset)
#     140
#     141         # Read data out
#
# KeyboardInterrupt:
